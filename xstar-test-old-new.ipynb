# %%
# %matplotlib inline

import matplotlib.pyplot as plt
from astropy.io import fits as pyfits
import numpy as np
from math import *

# %%
# Files
file1='/home/jerome/xstar2/june21/ioniz0/T1e5/1e15/xout_spect1.fits'
file2='/home/jerome/xstar2/june21/ioniz0/T1e5/1e15/HD/xout_spect1.fits'


# Read spectrum file 1
hdu1 = pyfits.open(file1)
ene1 = hdu1[2].data['energy']
tlum1 = hdu1[2].data['transmitted']
emit1 = hdu1[2].data['emit_outward']

# Read spectrum file 2
hdu2 = pyfits.open(file2)
ene2 = hdu2[2].data['energy']
tlum2 = hdu2[2].data['transmitted']
emit2 = hdu2[2].data['emit_outward']

# %%
# Clean the figure
plt.clf()

lw = 2   # Line widths throughout the plot
fsz = 16 # Font size throughout the plot
plt.rc('axes', labelsize=12)  # fontsize of the x any y labels

# Square figure
fig, (ax) = plt.subplots(1,1,facecolor='w',figsize=(6,4))

# Plot
#ax.semilogx(ene1,ene1*tlum1, label=r'DR')
#ax.semilogx(ene2,ene2*tlum2, 'r-',label=r'no DR')
ax.loglog(ene1,ene1*tlum1, label=r'Without HD')
ax.loglog(ene2,ene2*tlum2, 'r-',label=r'With HD')
#ax.set_xlim(3e3,2e4)
ax.set_ylim(10,1e20)

plt.legend(loc='best')

# Labels
plt.xlabel('Energy (eV)')
plt.ylabel('Luminosity (erg/s)')
plt.title ('$T = 10^5$ K, $n_e = 10^{15}$ cm$^{-3}$')

# -----------------------------------------------------------
plt.show()  #

# %%
# Files
file1='/home/jerome/xstar2/june21/ioniz0/T1e5/1e18/xout_spect1.fits'
file2='/home/jerome/xstar2/june21/ioniz0/T1e5/1e18/HD/xout_spect1.fits'


# Read spectrum file 1
hdu1 = pyfits.open(file1)
ene1 = hdu1[2].data['energy']
tlum1 = hdu1[2].data['transmitted']
emit1 = hdu1[2].data['emit_outward']

# Read spectrum file 2
hdu2 = pyfits.open(file2)
ene2 = hdu2[2].data['energy']
tlum2 = hdu2[2].data['transmitted']
emit2 = hdu2[2].data['emit_outward']

# %%
# Clean the figure
plt.clf()

lw = 2   # Line widths throughout the plot
fsz = 16 # Font size throughout the plot
plt.rc('axes', labelsize=12)  # fontsize of the x any y labels

# Square figure
fig, (ax) = plt.subplots(1,1,facecolor='w',figsize=(6,4))

# Plot
#ax.semilogx(ene1,ene1*tlum1, label=r'DR')
#ax.semilogx(ene2,ene2*tlum2, 'r-',label=r'no DR')
ax.loglog(ene1,ene1*tlum1, label=r'Without HD')
ax.loglog(ene2,ene2*tlum2, 'r-',label=r'With HD')
ax.set_xlim(3e3,2e4)
ax.set_ylim(10,1e20)

plt.legend(loc='best')

# Labels
plt.xlabel('Energy (eV)')
plt.ylabel('Luminosity (erg/s)')
plt.title ('$T = 10^5$ K, $n_e = 10^{18}$ cm$^{-3}$')

# -----------------------------------------------------------
plt.show()  #

# %%
# Files
file1='/home/jerome/xstar2/june21/ioniz0/T1e5/1e21/xout_spect1.fits'
file2='/home/jerome/xstar2/june21/ioniz0/T1e5/1e21/HD/xout_spect1.fits'


# Read spectrum file 1
hdu1 = pyfits.open(file1)
ene1 = hdu1[2].data['energy']
tlum1 = hdu1[2].data['transmitted']
emit1 = hdu1[2].data['emit_outward']

# Read spectrum file 2
hdu2 = pyfits.open(file2)
ene2 = hdu2[2].data['energy']
tlum2 = hdu2[2].data['transmitted']
emit2 = hdu2[2].data['emit_outward']

# %%
# Clean the figure
plt.clf()

lw = 2   # Line widths throughout the plot
fsz = 16 # Font size throughout the plot
plt.rc('axes', labelsize=12)  # fontsize of the x any y labels

# Square figure
fig, (ax) = plt.subplots(1,1,facecolor='w',figsize=(6,4))

# Plot
#ax.semilogx(ene1,ene1*tlum1, label=r'DR')
#ax.semilogx(ene2,ene2*tlum2, 'r-',label=r'no DR')
ax.loglog(ene1,ene1*tlum1, label=r'Without HD')
ax.loglog(ene2,ene2*tlum2, 'r-',label=r'With HD')
ax.set_xlim(2e3,1e4)
ax.set_ylim(10,1e20)

plt.legend(loc='best')

# Labels
plt.xlabel('Energy (eV)')
plt.ylabel('Luminosity (erg/s)')
plt.title ('$T = 10^5$ K, $n_e = 10^{21}$ cm$^{-3}$')

# -----------------------------------------------------------
plt.show()  #

# %%
# Files
file1='/home/jerome/xstar2/june21/ioniz0/T1e6/1e15/xout_spect1.fits'
file2='/home/jerome/xstar2/june21/ioniz0/T1e6/1e15/HD/xout_spect1.fits'

# Read spectrum file 1
hdu1 = pyfits.open(file1)
ene1 = hdu1[2].data['energy']
tlum1 = hdu1[2].data['transmitted']
emit1 = hdu1[2].data['emit_outward']

# Read spectrum file 2
hdu2 = pyfits.open(file2)
ene2 = hdu2[2].data['energy']
tlum2 = hdu2[2].data['transmitted']
emit2 = hdu2[2].data['emit_outward']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-ac11abdef6b2> in <module>
#       4
#       5 # Read spectrum file 1
# ----> 6 hdu1 = pyfits.open(file1)
#       7 ene1 = hdu1[2].data['energy']
#       8 tlum1 = hdu1[2].data['transmitted']
#
# ~/anaconda3/lib/python3.8/site-packages/astropy/io/fits/hdu/hdulist.py in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, **kwargs)
#     161         raise ValueError(f'Empty filename: {name!r}')
#     162
# --> 163     return HDUList.fromfile(name, mode, memmap, save_backup, cache,
#     164                             lazy_load_hdus, **kwargs)
#     165
#
# ~/anaconda3/lib/python3.8/site-packages/astropy/io/fits/hdu/hdulist.py in fromfile(cls, fileobj, mode, memmap, save_backup, cache, lazy_load_hdus, **kwargs)
#     398         """
#     399
# --> 400         return cls._readfrom(fileobj=fileobj, mode=mode, memmap=memmap,
#     401                              save_backup=save_backup, cache=cache,
#     402                              lazy_load_hdus=lazy_load_hdus, **kwargs)
#
# ~/anaconda3/lib/python3.8/site-packages/astropy/io/fits/hdu/hdulist.py in _readfrom(cls, fileobj, data, mode, memmap, cache, lazy_load_hdus, **kwargs)
#    1049             if not isinstance(fileobj, _File):
#    1050                 # instantiate a FITS file object (ffo)
# -> 1051                 fileobj = _File(fileobj, mode=mode, memmap=memmap, cache=cache)
#    1052             # The Astropy mode is determined by the _File initializer if the
#    1053             # supplied mode was None
#
# ~/anaconda3/lib/python3.8/site-packages/astropy/utils/decorators.py in wrapper(*args, **kwargs)
#     533                     warnings.warn(message, warning_type, stacklevel=2)
#     534
# --> 535             return function(*args, **kwargs)
#     536
#     537         return wrapper
#
# ~/anaconda3/lib/python3.8/site-packages/astropy/io/fits/file.py in __init__(self, fileobj, mode, memmap, overwrite, cache)
#     173             self._open_fileobj(fileobj, mode, overwrite)
#     174         elif isinstance(fileobj, (str, bytes)):
# --> 175             self._open_filename(fileobj, mode, overwrite)
#     176         else:
#     177             self._open_filelike(fileobj, mode, overwrite)
#
# ~/anaconda3/lib/python3.8/site-packages/astropy/io/fits/file.py in _open_filename(self, filename, mode, overwrite)
#     562
#     563         if not self._try_read_compressed(self.name, magic, mode, ext=ext):
# --> 564             self._file = fileobj_open(self.name, IO_FITS_MODES[mode])
#     565             self.close_on_error = True
#     566
#
# ~/anaconda3/lib/python3.8/site-packages/astropy/io/fits/util.py in fileobj_open(filename, mode)
#     395     """
#     396
# --> 397     return open(filename, mode, buffering=0)
#     398
#     399
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/jerome/xstar2/june21/ioniz0/T1e6/1e15/xout_spect1.fits'

# %%
# Clean the figure
plt.clf()

lw = 2   # Line widths throughout the plot
fsz = 16 # Font size throughout the plot
plt.rc('axes', labelsize=12)  # fontsize of the x any y labels

# Square figure
fig, (ax) = plt.subplots(1,1,facecolor='w',figsize=(6,4))

# Plot
#ax.semilogx(ene1,ene1*tlum1, label=r'DR')
#ax.semilogx(ene2,ene2*tlum2, 'r-',label=r'no DR')
ax.loglog(ene1,ene1*tlum1, label=r'Without HD')
ax.loglog(ene2,ene2*tlum2, 'r-',label=r'With HD')
ax.set_xlim(3e3,3e4)
ax.set_ylim(10,1e20)

plt.legend(loc='best')

# Labels
plt.xlabel('Energy (eV)')
plt.ylabel('Luminosity (erg/s)')
plt.title ('$T = 10^6$ K, $n_e = 10^{15}$ cm$^{-3}$')

# -----------------------------------------------------------
plt.show()  #

# %%
# Square figure
fig, (ax) = plt.subplots(1,1,facecolor='w',figsize=(6,4))

ax.semilogx(ene1,tlum2-tlum1, 'c')

# Labels
plt.xlabel('Energy (eV)')
plt.ylabel('Difference between HD and no HD')
plt.title ('$T = 10⁶$ K, $n_e = 10^{15}$ cm$^{-3}$')

#limits
plt.xlim(1e-1,1.e4)
#plt.ylim(,1.2)

# -----------------------------------------------------------
plt.show()  #

# %%
# Files
file1='/home/jerome/xstar2/june21/ioniz0/T1e6/1e18/xout_spect1.fits'
file2='/home/jerome/xstar2/june21/ioniz0/T1e6/1e18/HD/xout_spect1.fits'

# Read spectrum file 1
hdu1 = pyfits.open(file1)
ene1 = hdu1[2].data['energy']
tlum1 = hdu1[2].data['transmitted']
emit1 = hdu1[2].data['emit_outward']

# Read spectrum file 2
hdu2 = pyfits.open(file2)
ene2 = hdu2[2].data['energy']
tlum2 = hdu2[2].data['transmitted']
emit2 = hdu2[2].data['emit_outward']

# %%
# Clean the figure
plt.clf()

lw = 2   # Line widths throughout the plot
fsz = 16 # Font size throughout the plot
plt.rc('axes', labelsize=12)  # fontsize of the x any y labels

# Square figure
fig, (ax) = plt.subplots(1,1,facecolor='w',figsize=(6,4))

# Plot
#ax.semilogx(ene1,ene1*tlum1, label=r'DR')
#ax.semilogx(ene2,ene2*tlum2, 'r-',label=r'no DR')
ax.loglog(ene1,ene1*tlum1, label=r'Without HD')
ax.loglog(ene2,ene2*tlum2, 'r-',label=r'With HD')
ax.set_xlim(3e3,2e4)
ax.set_ylim(1e3,1e20)

plt.legend(loc='best')

# Labels
plt.xlabel('Energy (eV)')
plt.ylabel('Luminosity (erg/s)')
plt.title ('$T = 10⁶$ K, $n_e = 10^{18}$ cm$^{-3}$')

# -----------------------------------------------------------
plt.show()  #

# %%
# Square figure
fig, (ax) = plt.subplots(1,1,facecolor='w',figsize=(6,4))

ax.semilogx(ene1,tlum2-tlum1, 'c')

# Labels
plt.xlabel('Energy (eV)')
plt.ylabel('Difference between HD and no HD')
plt.title ('$T = 10⁶$ K, $n_e = 10^{18}$ cm$^{-3}$')

#limits
#plt.xlim(9e3,2e4)
#plt.ylim(,1.2)

# -----------------------------------------------------------
plt.show()  #

# %%
# Files
file1='/home/jerome/xstar2/june21/ioniz0/T1e6/1e21/xout_spect1.fits'
file2='/home/jerome/xstar2/june21/ioniz0/T1e6/1e21/HD/xout_spect1.fits'

# Read spectrum file 1
hdu1 = pyfits.open(file1)
ene1 = hdu1[2].data['energy']
tlum1 = hdu1[2].data['transmitted']
emit1 = hdu1[2].data['emit_outward']

# Read spectrum file 2
hdu2 = pyfits.open(file2)
ene2 = hdu2[2].data['energy']
tlum2 = hdu2[2].data['transmitted']
emit2 = hdu2[2].data['emit_outward']

# %%
# Clean the figure
plt.clf()

lw = 2   # Line widths throughout the plot
fsz = 16 # Font size throughout the plot
plt.rc('axes', labelsize=12)  # fontsize of the x any y labels

# Square figure
fig, (ax) = plt.subplots(1,1,facecolor='w',figsize=(6,4))

# Plot
#ax.semilogx(ene1,ene1*tlum1, label=r'DR')
#ax.semilogx(ene2,ene2*tlum2, 'r-',label=r'no DR')
ax.loglog(ene1,ene1*tlum1, label=r'Without HD')
ax.loglog(ene2,ene2*tlum2, 'r-',label=r'With HD')
ax.set_xlim(3e3,2e4)
ax.set_ylim(1e3,1e20)

plt.legend(loc='best')

# Labels
plt.xlabel('Energy (eV)')
plt.ylabel('Luminosity (erg/s)')
plt.title ('$T = 10⁶$ K, $n_e = 10^{21}$ cm$^{-3}$')

# -----------------------------------------------------------
plt.show()  #

# %%
# Square figure
fig, (ax) = plt.subplots(1,1,facecolor='w',figsize=(6,4))

ax.semilogx(ene1,tlum2-tlum1, 'c')

# Labels
plt.xlabel('Energy (eV)')
plt.ylabel('Difference between HD and no HD')
plt.title ('$T = 10⁶$ K, $n_e = 10^{21}$ cm$^{-3}$')

#limits
plt.xlim(3e3,4e4)
#plt.ylim(,1.2)

# -----------------------------------------------------------
plt.show()  #

# %%
# Files
file1='/home/jerome/xstar2/june21/ioniz0/T1e7/1e15/xout_spect1.fits'
file2='/home/jerome/xstar2/june21/ioniz0/T1e7/1e15/HD/xout_spect1.fits'

# Read spectrum file 1
hdu1 = pyfits.open(file1)
ene1 = hdu1[2].data['energy']
tlum1 = hdu1[2].data['transmitted']
emit1 = hdu1[2].data['emit_outward']

# Read spectrum file 2
hdu2 = pyfits.open(file2)
ene2 = hdu2[2].data['energy']
tlum2 = hdu2[2].data['transmitted']
emit2 = hdu2[2].data['emit_outward']

# %%
# Clean the figure
plt.clf()

lw = 2   # Line widths throughout the plot
fsz = 16 # Font size throughout the plot
plt.rc('axes', labelsize=12)  # fontsize of the x any y labels

# Square figure
fig, (ax) = plt.subplots(1,1,facecolor='w',figsize=(6,4))

# Plot
#ax.semilogx(ene1,ene1*tlum1, label=r'DR')
#ax.semilogx(ene2,ene2*tlum2, 'r-',label=r'no DR')
ax.loglog(ene1,ene1*tlum1, label=r'Without HD')
ax.loglog(ene2,ene2*tlum2, 'r-',label=r'With HD')
#ax.set_xlim(5e3,7e3)
ax.set_ylim(1e3,1e20)

plt.legend(loc='best')

# Labels
plt.xlabel('Energy (eV)')
plt.ylabel('Luminosity (erg/s)')
plt.title ('$T = 10⁷$ K, $n_e = 10^{15}$ cm$^{-3}$')

# -----------------------------------------------------------
plt.show()  #

# %%
# Square figure
fig, (ax) = plt.subplots(1,1,facecolor='w',figsize=(6,4))

ax.semilogx(ene1,(tlum2-tlum1)/(tlum2+tlum1), 'c')

# Labels
plt.xlabel('Energy (eV)')
plt.ylabel('Difference between HD and no HD')
plt.title ('$T = 10^7$ K, $n_e = 10^{15}$ cm$^{-3}$')

#limits
#plt.xlim(4e3,8e3)
#plt.ylim(,1.2)

# -----------------------------------------------------------
plt.show()  #
# Out:
# <ipython-input-24-555c04623475>:4: RuntimeWarning: invalid value encountered in true_divide
#   ax.semilogx(ene1,(tlum2-tlum1)/(tlum2+tlum1), 'c')

# %%
# Files
file1='/home/jerome/xstar2/june21/ioniz0/T1e7/1e18/xout_spect1.fits'
file2='/home/jerome/xstar2/june21/ioniz0/T1e7/1e18/HD/xout_spect1.fits'

# Read spectrum file 1
hdu1 = pyfits.open(file1)
ene1 = hdu1[2].data['energy']
tlum1 = hdu1[2].data['transmitted']
emit1 = hdu1[2].data['emit_outward']

# Read spectrum file 2
hdu2 = pyfits.open(file2)
ene2 = hdu2[2].data['energy']
tlum2 = hdu2[2].data['transmitted']
emit2 = hdu2[2].data['emit_outward']

# %%
# Clean the figure
plt.clf()

lw = 2   # Line widths throughout the plot
fsz = 16 # Font size throughout the plot
plt.rc('axes', labelsize=12)  # fontsize of the x any y labels

# Square figure
fig, (ax) = plt.subplots(1,1,facecolor='w',figsize=(6,4))

# Plot
#ax.semilogx(ene1,ene1*tlum1, label=r'DR')
#ax.semilogx(ene2,ene2*tlum2, 'r-',label=r'no DR')
ax.loglog(ene1,ene1*tlum1, label=r'Without HD')
ax.loglog(ene2,ene2*tlum2, 'r-',label=r'With HD')
#ax.set_xlim(5e3,8e3)
ax.set_ylim(1e3,1e20)

plt.legend(loc='best')

# Labels
plt.xlabel('Energy (eV)')
plt.ylabel('Luminosity (erg/s)')
plt.title ('$T = 10⁷$ K, $n_e = 10^{18}$ cm$^{-3}$')

# -----------------------------------------------------------
plt.show()  #

# %%
# Square figure
fig, (ax) = plt.subplots(1,1,facecolor='w',figsize=(6,4))

ax.semilogx(ene1,(tlum2-tlum1)/(tlum2+tlum1), 'c')

# Labels
plt.xlabel('Energy (eV)')
plt.ylabel('Difference between HD and no HD')
plt.title ('$T = 10^7$ K, $n_e = 10^{18}$ cm$^{-3}$')

#limits
#plt.xlim(4e3,8e3)
#plt.ylim(,1.2)

# -----------------------------------------------------------
plt.show()  #
# Out:
# <ipython-input-21-555c04623475>:4: RuntimeWarning: invalid value encountered in true_divide
#   ax.semilogx(ene1,(tlum2-tlum1)/(tlum2+tlum1), 'c')

# %%
# Files
file1='/home/jerome/xstar2/june21/ioniz0/T1e7/1e21/xout_spect1.fits'
file2='/home/jerome/xstar2/june21/ioniz0/T1e7/1e21/HD/xout_spect1.fits'

# Read spectrum file 1
hdu1 = pyfits.open(file1)
ene1 = hdu1[2].data['energy']
tlum1 = hdu1[2].data['transmitted']
emit1 = hdu1[2].data['emit_outward']

# Read spectrum file 2
hdu2 = pyfits.open(file2)
ene2 = hdu2[2].data['energy']
tlum2 = hdu2[2].data['transmitted']
emit2 = hdu2[2].data['emit_outward']

# %%
# Clean the figure
plt.clf()

lw = 2   # Line widths throughout the plot
fsz = 16 # Font size throughout the plot
plt.rc('axes', labelsize=12)  # fontsize of the x any y labels

# Square figure
fig, (ax) = plt.subplots(1,1,facecolor='w',figsize=(6,4))

# Plot
#ax.semilogx(ene1,ene1*tlum1, label=r'DR')
#ax.semilogx(ene2,ene2*tlum2, 'r-',label=r'no DR')
ax.loglog(ene1,ene1*tlum1, label=r'Without HD')
ax.loglog(ene2,ene2*tlum2, 'r-',label=r'With HD')
ax.set_xlim(5e0,2e4)
ax.set_xlim(1e2,2e4)
ax.set_ylim(1e3,1e20)

plt.legend(loc='best')

# Labels
plt.xlabel('Energy (eV)')
plt.ylabel('Luminosity (erg/s)')
plt.title ('$T = 10⁷$ K, $n_e = 10^{21}$ cm$^{-3}$')

# -----------------------------------------------------------
plt.show()  #

# %%
# Square figure
fig, (ax) = plt.subplots(1,1,facecolor='w',figsize=(6,4))

ax.semilogx(ene1,(tlum2-tlum1)/(tlum2+tlum1), 'c')

# Labels
plt.xlabel('Energy (eV)')
plt.ylabel('Difference between HD and no HD')
plt.title ('$T = 10^7$ K, $n_e = 10^{21}$ cm$^{-3}$')

#limits
#plt.xlim(4e3,8e3)
#plt.ylim(,1.2)

# -----------------------------------------------------------
plt.show()  #
# Out:
# <ipython-input-18-555c04623475>:4: RuntimeWarning: invalid value encountered in true_divide
#   ax.semilogx(ene1,(tlum2-tlum1)/(tlum2+tlum1), 'c')
