# %%
# %matplotlib inline

import matplotlib.pyplot as plt
from astropy.io import fits as pyfits
import numpy as np
from math import *

# %%
# User Adjustable Parameters
#
cfrac,r,h,1.,0.,1.,"covering fraction"
#
temperature,r,h,1.e1,0.,1.e4,"temperature (/10**4K)"
#
lcpres,i,h,0,0,1,"constant pressure switch (1=yes, 0=no)"
#
pressure,r,h,0.03,0.,1.,"pressure (dyne/cm**2)"
#
density,r,h,1.e+15,0.,1.e22,"density (cm**-3)"
#
spectrum,s,h,"pow",,,"spectrum type?"
#
spectrum_file,s,h,"spct.dat",,,"spectrum file?"
#
spectun,i,h,0,0,1,"spectrum units? (0=energy, 1=photons)"
#
trad,r,h,-1,,,"radiation temperature or alpha?"
#
rlrad38,r,h,1.e8,0.,1.e10,"luminosity (/10**38 erg/s)"
#
column,r,h,1.E23,0.,1.e25,"column density (cm**-2)"
#
rlogxi,r,h,0.,-10.,+10.,"log(ionization parameter) (erg cm/s)"
#
habund,r,h,1.,0.,100.,"hydrogen abundance"
#
heabund,r,h,1.,0.,100.,"helium abundance"
#
liabund,r,h,0,0.,100.,"lithium abundance"
#
beabund,r,h,0,0.,100.,"beryllium abundance"
#
babund,r,h,0,0.,100.,"boron abundance"
#
cabund,r,h,1,0.,100.,"carbon abundance"
#
nabund,r,h,1,0.,100.,"nitrogen abundance"
#
oabund,r,h,1,0.,100.,"oxygen abundance"
#
fabund,r,h,0.0,0.,100.,"fluorine abundance"
#
neabund,r,h,1,0.,100.,"neon abundance"
#
naabund,r,h,0.0,0.,100.,"sodium abundance"
#
mgabund,r,h,1,0.,100.,"magnesium abundance"
#
alabund,r,h,0.0,0.,100.,"aluminum abundance"
#
siabund,r,h,1,0.,100.,"silicon abundance"
#
pabund,r,h,0.0,0.,100.,"phosphorus abundance"
#
sabund,r,h,1,0.,100.,"sulfur abundance"
#
clabund,r,h,0.0,0.,100.,"chlorine abundance"
#
arabund,r,h,1,0.,100.,"argon abundance"
#
kabund,r,h,0.0,0.,100.,"potassium abundance"
#
caabund,r,h,1,0.,100.,"calcium abundance"
#
scabund,r,h,0.0,0.,100.,"scandium abundance"
#
tiabund,r,h,0.0,0.,100.,"titanium abundance"
#
vabund,r,h,0,0.,100.,"vanadium abundance"
#
crabund,r,h,0.0,0.,100.,"chromium abundance"
#
mnabund,r,h,0.0,0.,100.,"manganese abundance"
#
feabund,r,h,1,0.,100.,"iron abundance"
#
coabund,r,h,0.0,0.,100.,"cobalt abundance"
#
niabund,r,h,1,0.,100.,"nickel abundance"
#
cuabund,r,h,0.0,0.,100.,"copper abundance"
#
znabund,r,h,0.0,0.,100.,"zinc abundance"

# %%
# Files
file1='/home/jerome/xstar2/june21/ioniz0/N23/T1e5/1e15/xout_spect1.fits'
file2='/home/jerome/xstar2/june21/ioniz0/N23/T1e5/1e15/HD/xout_spect1.fits'


# Read spectrum file 1
hdu1 = pyfits.open(file1)
ene1 = hdu1[2].data['energy']
tlum1 = hdu1[2].data['transmitted']
emit1 = hdu1[2].data['emit_outward']

# Read spectrum file 2
hdu2 = pyfits.open(file2)
ene2 = hdu2[2].data['energy']
tlum2 = hdu2[2].data['transmitted']
emit2 = hdu2[2].data['emit_outward']

# %%
# Clean the figure
plt.clf()

lw = 2   # Line widths throughout the plot
fsz = 16 # Font size throughout the plot
plt.rc('axes', labelsize=12)  # fontsize of the x any y labels

# Square figure
fig, (ax) = plt.subplots(1,1,facecolor='w',figsize=(6,4))

# Plot
#ax.semilogx(ene1,ene1*tlum1, label=r'DR')
#ax.semilogx(ene2,ene2*tlum2, 'r-',label=r'no DR')
ax.loglog(ene1,ene1*tlum1, label=r'Without HD')
ax.loglog(ene2,ene2*tlum2, 'r-',label=r'With HD')
ax.set_xlim(1.5e2,1e4)
ax.set_ylim(10,1e20)

plt.legend(loc='best')

# Labels
plt.xlabel('Energy (eV)')
plt.ylabel('Luminosity (erg/s)')
plt.title ('$T = 10^5$ K, $n_e = 10^{15}$ cm$^{-3}$')
plt.savefig('T1e5n1e15.pdf')

# -----------------------------------------------------------
plt.show()  #

# %%
# Files
file1='/home/jerome/xstar2/june21/ioniz0/N23/T1e5/1e18/xout_spect1.fits'
file2='/home/jerome/xstar2/june21/ioniz0/N23/T1e5/1e18/HD/xout_spect1.fits'


# Read spectrum file 1
hdu1 = pyfits.open(file1)
ene1 = hdu1[2].data['energy']
tlum1 = hdu1[2].data['transmitted']
emit1 = hdu1[2].data['emit_outward']

# Read spectrum file 2
hdu2 = pyfits.open(file2)
ene2 = hdu2[2].data['energy']
tlum2 = hdu2[2].data['transmitted']
emit2 = hdu2[2].data['emit_outward']

# %%
# Clean the figure
plt.clf()

lw = 2   # Line widths throughout the plot
fsz = 16 # Font size throughout the plot
plt.rc('axes', labelsize=12)  # fontsize of the x any y labels

# Square figure
fig, (ax) = plt.subplots(1,1,facecolor='w',figsize=(6,4))

# Plot
#ax.semilogx(ene1,ene1*tlum1, label=r'DR')
#ax.semilogx(ene2,ene2*tlum2, 'r-',label=r'no DR')
ax.loglog(ene1,ene1*tlum1, label=r'Without HD')
ax.loglog(ene2,ene2*tlum2, 'r-',label=r'With HD')
ax.set_xlim(1.5e2,1e4)
ax.set_ylim(10,1e20)

plt.legend(loc='best')

# Labels
plt.xlabel('Energy (eV)')
plt.ylabel('Luminosity (erg/s)')
plt.title ('$T = 10^5$ K, $n_e = 10^{18}$ cm$^{-3}$')
plt.savefig('T1e5n1e18.pdf')

# -----------------------------------------------------------
plt.show()  #

# %%
# Files
file1='/home/jerome/xstar2/june21/ioniz0/N23/T1e5/1e21/xout_spect1.fits'
file2='/home/jerome/xstar2/june21/ioniz0/N23/T1e5/1e21/HD/xout_spect1.fits'


# Read spectrum file 1
hdu1 = pyfits.open(file1)
ene1 = hdu1[2].data['energy']
tlum1 = hdu1[2].data['transmitted']
emit1 = hdu1[2].data['emit_outward']

# Read spectrum file 2
hdu2 = pyfits.open(file2)
ene2 = hdu2[2].data['energy']
tlum2 = hdu2[2].data['transmitted']
emit2 = hdu2[2].data['emit_outward']

# %%
# Clean the figure
plt.clf()

lw = 2   # Line widths throughout the plot
fsz = 16 # Font size throughout the plot
plt.rc('axes', labelsize=12)  # fontsize of the x any y labels

# Square figure
fig, (ax) = plt.subplots(1,1,facecolor='w',figsize=(6,4))

# Plot
#ax.semilogx(ene1,ene1*tlum1, label=r'DR')
#ax.semilogx(ene2,ene2*tlum2, 'r-',label=r'no DR')
ax.loglog(ene1,ene1*tlum1, label=r'Without HD')
ax.loglog(ene2,ene2*tlum2, 'r-',label=r'With HD')
ax.set_xlim(3e2,1e4)
ax.set_ylim(10,1e20)

plt.legend(loc='best')

# Labels
plt.xlabel('Energy (eV)')
plt.ylabel('Luminosity (erg/s)')
plt.title ('$T = 10^5$ K, $n_e = 10^{21}$ cm$^{-3}$')
plt.savefig('T1e5n1e21.pdf')

# -----------------------------------------------------------
plt.show()  #

# %%
# Files
file1='/home/jerome/xstar2/june21/ioniz0/N23/T1e6/1e12/xout_spect1.fits'
file2='/home/jerome/xstar2/june21/ioniz0/N23/T1e6/1e12/HD/xout_spect1.fits'

# Read spectrum file 1
hdu1 = pyfits.open(file1)
ene1 = hdu1[2].data['energy']
tlum1 = hdu1[2].data['transmitted']
emit1 = hdu1[2].data['emit_outward']

# Read spectrum file 2
hdu2 = pyfits.open(file2)
ene2 = hdu2[2].data['energy']
tlum2 = hdu2[2].data['transmitted']
emit2 = hdu2[2].data['emit_outward']

# %%
# Clean the figure
plt.clf()

lw = 2   # Line widths throughout the plot
fsz = 16 # Font size throughout the plot
plt.rc('axes', labelsize=12)  # fontsize of the x any y labels

# Square figure
fig, (ax) = plt.subplots(1,1,facecolor='w',figsize=(6,4))

# Plot
#ax.semilogx(ene1,ene1*tlum1, label=r'DR')
#ax.semilogx(ene2,ene2*tlum2, 'r-',label=r'no DR')
ax.loglog(ene1,ene1*tlum1, label=r'Without HD')
ax.loglog(ene2,ene2*tlum2, 'r-',label=r'With HD')
ax.set_xlim(1e-1,2e4)
#ax.set_xlim(2e3,2e4)
ax.set_ylim(10,1e20)

plt.legend(loc='best')

# Labels
plt.xlabel('Energy (eV)')
plt.ylabel('Luminosity (erg/s)')
plt.title ('$T = 10^6$ K, $n_e = 10^{12}$ cm$^{-3}$')
plt.savefig('T1e6n1e15.pdf')

# -----------------------------------------------------------
plt.show()  #

# %%
# Files
file1='/home/jerome/xstar2/june21/ioniz0/N23/T1e6/1e15/xout_spect1.fits'
file2='/home/jerome/xstar2/june21/ioniz0/N23/T1e6/1e15/HD/xout_spect1.fits'

# Read spectrum file 1
hdu1 = pyfits.open(file1)
ene1 = hdu1[2].data['energy']
tlum1 = hdu1[2].data['transmitted']
emit1 = hdu1[2].data['emit_outward']

# Read spectrum file 2
hdu2 = pyfits.open(file2)
ene2 = hdu2[2].data['energy']
tlum2 = hdu2[2].data['transmitted']
emit2 = hdu2[2].data['emit_outward']

# %%
# Clean the figure
plt.clf()

lw = 2   # Line widths throughout the plot
fsz = 16 # Font size throughout the plot
plt.rc('axes', labelsize=12)  # fontsize of the x any y labels

# Square figure
fig, (ax) = plt.subplots(1,1,facecolor='w',figsize=(6,4))

# Plot
#ax.semilogx(ene1,ene1*tlum1, label=r'DR')
#ax.semilogx(ene2,ene2*tlum2, 'r-',label=r'no DR')
ax.loglog(ene1,ene1*tlum1, label=r'Without HD')
ax.loglog(ene2,ene2*tlum2, 'r-',label=r'With HD')
ax.set_xlim(1e-1,2e4)
#ax.set_xlim(2e3,2e4)
ax.set_ylim(10,1e20)

plt.legend(loc='best')

# Labels
plt.xlabel('Energy (eV)')
plt.ylabel('Luminosity (erg/s)')
plt.title ('$T = 10^6$ K, $n_e = 10^{15}$ cm$^{-3}$')
plt.savefig('T1e6n1e15.pdf')

# -----------------------------------------------------------
plt.show()  #

# %%
# Square figure
fig, (ax) = plt.subplots(1,1,facecolor='w',figsize=(6,4))

ax.semilogx(ene1,tlum2-tlum1, 'c')

# Labels
plt.xlabel('Energy (eV)')
plt.ylabel('Difference between HD and no HD')
plt.title ('$T = 10⁶$ K, $n_e = 10^{15}$ cm$^{-3}$')

#limits
plt.xlim(1e-1,1.e4)
#plt.ylim(,1.2)

# -----------------------------------------------------------
plt.show()  #

# %%
# Files
file1='/home/jerome/xstar2/june21/ioniz0/N23/T1e6/1e18/xout_spect1.fits'
file2='/home/jerome/xstar2/june21/ioniz0/N23/T1e6/1e18/HD/xout_spect1.fits'

# Read spectrum file 1
hdu1 = pyfits.open(file1)
ene1 = hdu1[2].data['energy']
tlum1 = hdu1[2].data['transmitted']
emit1 = hdu1[2].data['emit_outward']

# Read spectrum file 2
hdu2 = pyfits.open(file2)
ene2 = hdu2[2].data['energy']
tlum2 = hdu2[2].data['transmitted']
emit2 = hdu2[2].data['emit_outward']

# %%
# Clean the figure
plt.clf()

lw = 2   # Line widths throughout the plot
fsz = 16 # Font size throughout the plot
plt.rc('axes', labelsize=12)  # fontsize of the x any y labels

# Square figure
fig, (ax) = plt.subplots(1,1,facecolor='w',figsize=(6,4))

# Plot
#ax.semilogx(ene1,ene1*tlum1, label=r'DR')
#ax.semilogx(ene2,ene2*tlum2, 'r-',label=r'no DR')
ax.loglog(ene1,ene1*tlum1, label=r'Without HD')
ax.loglog(ene2,ene2*tlum2, 'r-',label=r'With HD')
ax.set_xlim(1e0,2e4)
ax.set_ylim(1e3,1e20)

plt.legend(loc='best')

# Labels
plt.xlabel('Energy (eV)')
plt.ylabel('Luminosity (erg/s)')
plt.title ('$T = 10⁶$ K, $n_e = 10^{18}$ cm$^{-3}$')
plt.savefig('T1e6n1e18.pdf')

# -----------------------------------------------------------
plt.show()  #

# %%
# Files
file1='/home/jerome/xstar2/june21/ioniz0/N23/T1e6/1e21/xout_spect1.fits'
file2='/home/jerome/xstar2/june21/ioniz0/N23/T1e6/1e21/HD/xout_spect1.fits'

# Read spectrum file 1
hdu1 = pyfits.open(file1)
ene1 = hdu1[2].data['energy']
tlum1 = hdu1[2].data['transmitted']
emit1 = hdu1[2].data['emit_outward']

# Read spectrum file 2
hdu2 = pyfits.open(file2)
ene2 = hdu2[2].data['energy']
tlum2 = hdu2[2].data['transmitted']
emit2 = hdu2[2].data['emit_outward']

# %%
# Clean the figure
plt.clf()

lw = 2   # Line widths throughout the plot
fsz = 16 # Font size throughout the plot
plt.rc('axes', labelsize=12)  # fontsize of the x any y labels

# Square figure
fig, (ax) = plt.subplots(1,1,facecolor='w',figsize=(6,4))

# Plot
#ax.semilogx(ene1,ene1*tlum1, label=r'DR')
#ax.semilogx(ene2,ene2*tlum2, 'r-',label=r'no DR')
ax.loglog(ene1,ene1*tlum1, label=r'Without HD')
ax.loglog(ene2,ene2*tlum2, 'r-',label=r'With HD')
ax.set_xlim(4e1,2e4)
ax.set_ylim(1e3,1e20)

plt.legend(loc='best')

# Labels
plt.xlabel('Energy (eV)')
plt.ylabel('Luminosity (erg/s)')
plt.title ('$T = 10⁶$ K, $n_e = 10^{21}$ cm$^{-3}$')
plt.savefig('T1e6n1e21.pdf')

# -----------------------------------------------------------
plt.show()  #

# %%
# Files
file1='/home/jerome/xstar2/june21/ioniz0/N23/T1e7/1e12/xout_spect1.fits'
file2='/home/jerome/xstar2/june21/ioniz0/N23/T1e7/1e12/HD/xout_spect1.fits'

# Read spectrum file 1
hdu1 = pyfits.open(file1)
ene1 = hdu1[2].data['energy']
tlum1 = hdu1[2].data['transmitted']
emit1 = hdu1[2].data['emit_outward']

# Read spectrum file 2
hdu2 = pyfits.open(file2)
ene2 = hdu2[2].data['energy']
tlum2 = hdu2[2].data['transmitted']
emit2 = hdu2[2].data['emit_outward']

# %%
# Clean the figure
plt.clf()

lw = 2   # Line widths throughout the plot
fsz = 16 # Font size throughout the plot
plt.rc('axes', labelsize=12)  # fontsize of the x any y labels

# Square figure
fig, (ax) = plt.subplots(1,1,facecolor='w',figsize=(6,4))

# Plot
#ax.semilogx(ene1,ene1*tlum1, label=r'DR')
#ax.semilogx(ene2,ene2*tlum2, 'r-',label=r'no DR')
ax.loglog(ene1,ene1*tlum1, label=r'Without HD')
ax.loglog(ene2,ene2*tlum2, 'r-',label=r'With HD')
ax.set_xlim(0.5e3,10e3)
#ax.set_xlim(1e0,4e4)
ax.set_ylim(5e16,2e19)

plt.legend(loc='best')

# Labels
plt.xlabel('Energy (eV)')
plt.ylabel('Luminosity (erg/s)')
plt.title ('$T = 10⁷$ K, $n_e = 10^{12}$ cm$^{-3}$')
plt.savefig('T1e7n1e12.pdf')

# -----------------------------------------------------------
plt.show()  #

# %%
# Files
file1='/home/jerome/xstar2/june21/ioniz0/N23/T1e7/1e15/xout_spect1.fits'
file2='/home/jerome/xstar2/june21/ioniz0/N23/T1e7/1e15/HD/xout_spect1.fits'

# Read spectrum file 1
hdu1 = pyfits.open(file1)
ene1 = hdu1[2].data['energy']
tlum1 = hdu1[2].data['transmitted']
emit1 = hdu1[2].data['emit_outward']

# Read spectrum file 2
hdu2 = pyfits.open(file2)
ene2 = hdu2[2].data['energy']
tlum2 = hdu2[2].data['transmitted']
emit2 = hdu2[2].data['emit_outward']

# %%
# Clean the figure
plt.clf()

lw = 2   # Line widths throughout the plot
fsz = 16 # Font size throughout the plot
plt.rc('axes', labelsize=12)  # fontsize of the x any y labels

# Square figure
fig, (ax) = plt.subplots(1,1,facecolor='w',figsize=(6,4))

# Plot
#ax.semilogx(ene1,ene1*tlum1, label=r'DR')
#ax.semilogx(ene2,ene2*tlum2, 'r-',label=r'no DR')
ax.loglog(ene1,ene1*tlum1, label=r'Without HD')
ax.loglog(ene2,ene2*tlum2, 'r-',label=r'With HD')
ax.set_xlim(0.5e3,10e3)
#ax.set_xlim(1e0,4e4)
ax.set_ylim(5e16,2e19)

plt.legend(loc='best')

# Labels
plt.xlabel('Energy (eV)')
plt.ylabel('Luminosity (erg/s)')
plt.title ('$T = 10⁷$ K, $n_e = 10^{15}$ cm$^{-3}$')
plt.savefig('T1e7n1e15.pdf')

# -----------------------------------------------------------
plt.show()  #

# %%
# Files
file1='/home/jerome/xstar2/june21/ioniz0/N23/T1e7/1e18/xout_spect1.fits'
file2='/home/jerome/xstar2/june21/ioniz0/N23/T1e7/1e18/HD/xout_spect1.fits'

# Read spectrum file 1
hdu1 = pyfits.open(file1)
ene1 = hdu1[2].data['energy']
tlum1 = hdu1[2].data['transmitted']
emit1 = hdu1[2].data['emit_outward']

# Read spectrum file 2
hdu2 = pyfits.open(file2)
ene2 = hdu2[2].data['energy']
tlum2 = hdu2[2].data['transmitted']
emit2 = hdu2[2].data['emit_outward']

# %%
# Clean the figure
plt.clf()

lw = 2   # Line widths throughout the plot
fsz = 16 # Font size throughout the plot
plt.rc('axes', labelsize=12)  # fontsize of the x any y labels

# Square figure
fig, (ax) = plt.subplots(1,1,facecolor='w',figsize=(6,4))

# Plot
#ax.semilogx(ene1,ene1*tlum1, label=r'DR')
#ax.semilogx(ene2,ene2*tlum2, 'r-',label=r'no DR')
ax.loglog(ene1,ene1*tlum1, label=r'Without HD')
ax.loglog(ene2,ene2*tlum2, 'r-',label=r'With HD')
ax.set_xlim(0.5e3,10e3)
ax.set_ylim(5e16,2e19)

plt.legend(loc='best')

# Labels
plt.xlabel('Energy (eV)')
plt.ylabel('Luminosity (erg/s)')
plt.title ('$T = 10⁷$ K, $n_e = 10^{18}$ cm$^{-3}$')
plt.savefig('T1e7n1e18.pdf')

# -----------------------------------------------------------
plt.show()  #

# %%
# Files
file1='/home/jerome/xstar2/june21/ioniz0/N23/T1e7/1e21/xout_spect1.fits'
file2='/home/jerome/xstar2/june21/ioniz0/N23/T1e7/1e21/HD/xout_spect1.fits'

# Read spectrum file 1
hdu1 = pyfits.open(file1)
ene1 = hdu1[2].data['energy']
tlum1 = hdu1[2].data['transmitted']
emit1 = hdu1[2].data['emit_outward']

# Read spectrum file 2
hdu2 = pyfits.open(file2)
ene2 = hdu2[2].data['energy']
tlum2 = hdu2[2].data['transmitted']
emit2 = hdu2[2].data['emit_outward']

# %%
# Clean the figure
plt.clf()

lw = 2   # Line widths throughout the plot
fsz = 16 # Font size throughout the plot
plt.rc('axes', labelsize=12)  # fontsize of the x any y labels

# Square figure
fig, (ax) = plt.subplots(1,1,facecolor='w',figsize=(6,4))

# Plot
#ax.semilogx(ene1,ene1*tlum1, label=r'DR')
#ax.semilogx(ene2,ene2*tlum2, 'r-',label=r'no DR')
ax.loglog(ene1,ene1*tlum1, label=r'Without HD')
ax.loglog(ene2,ene2*tlum2, 'r-',label=r'With HD')
#ax.set_xlim(5e0,2e4)
ax.set_xlim(0.5e3,1e4)
ax.set_ylim(5e16,2e19)

plt.legend(loc='best')

# Labels
plt.xlabel('Energy (eV)')
plt.ylabel('Luminosity (erg/s)')
plt.title ('$T = 10⁷$ K, $n_e = 10^{21}$ cm$^{-3}$')
plt.savefig('T1e7n1e21.pdf')

# -----------------------------------------------------------
plt.show()  #
